# %%
import pandas as pd

# %%
#강남구 음식점 데이터 처리
df = pd.read_csv("/Users/juhong/Library/CloudStorage/OneDrive-아주대학교/대학교/3학년 2학기/캡스톤/직접 연계 통계 모음/모음/서울시 일반음식점 인허가 정보.csv",encoding = 'UTF8')
# Out:
# /var/folders/d2/20dks6yj46b_077x0h5fmr740000gn/T/ipykernel_4411/4044769623.py:2: DtypeWarning: Columns (25,27,28,29,30,36,39,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/juhong/Library/CloudStorage/OneDrive-아주대학교/대학교/3학년 2학기/캡스톤/직접 연계 통계 모음/모음/서울시 일반음식점 인허가 정보.csv",encoding = 'UTF8')

# %%
df['지번주소'].head()
# Out:
# 0     서울특별시 종로구 평창동 110-1번지
# 1        서울특별시 종로구 인사동 98번지
# 2    서울특별시 종로구 종로6가 129-1번지
# 3        서울특별시 종로구 통인동 27-2
# 4       서울특별시 종로구 창신동 696-1
# Name: 지번주소, dtype: object

# %%
df.dtypes
# Out:
# 개방자치단체코드       int64
# 관리번호          object
# 인허가일자          int64
# 인허가취소일자      float64
# 영업상태코드         int64
# 영업상태명         object
# 상세영업상태코드       int64
# 상세영업상태명       object
# 폐업일자         float64
# 휴업시작일자       float64
# 휴업종료일자       float64
# 재개업일자        float64
# 전화번호          object
# 소재지면적        float64
# 소재지우편번호      float64
# 지번주소          object
# 도로명주소         object
# 도로명우편번호      float64
# 사업장명          object
# 최종수정일자       float64
# 데이터갱신구분       object
# 데이터갱신일자       object
# 업태구분명         object
# 좌표정보(X)      float64
# 좌표정보(Y)      float64
# 위생업태명         object
# 남성종사자수       float64
# 여성종사자수        object
# 영업장주변구분명      object
# 등급구분명         object
# 급수시설구분명       object
# 총인원          float64
# 본사종업원수       float64
# 공장사무직종업원수    float64
# 공장판매직종업원수    float64
# 공장생산직종업원수    float64
# 건물소유구분명       object
# 보증액          float64
# 월세액          float64
# 다중이용업소여부      object
# 시설총규모        float64
# 전통업소지정번호      object
# 전통업소주된음식      object
# ...

# %%
del df['전통업소주된음식']

# %%
del df['시설총규모']
del df['전통업소지정번호']
del df['홈페이지']
del df['다중이용업소여부']
del df['월세액']
del df['보증액']
del df['건물소유구분명']
del df['공장생산직종업원수']
del df['공장판매직종업원수']
del df['공장사무직종업원수']
del df['본사종업원수']
del df['총인원']
del df['급수시설구분명']
del df['등급구분명']
del df['남성종사자수']
del df['여성종사자수']
del df['위생업태명']

# %%
df.dtypes
# Out:
# 개방자치단체코드      int64
# 관리번호         object
# 인허가일자         int64
# 인허가취소일자     float64
# 영업상태코드        int64
# 영업상태명        object
# 상세영업상태코드      int64
# 상세영업상태명      object
# 폐업일자        float64
# 휴업시작일자      float64
# 휴업종료일자      float64
# 재개업일자       float64
# 전화번호         object
# 소재지면적       float64
# 소재지우편번호     float64
# 지번주소         object
# 도로명주소        object
# 도로명우편번호     float64
# 사업장명         object
# 최종수정일자      float64
# 데이터갱신구분      object
# 데이터갱신일자      object
# 업태구분명        object
# 좌표정보(X)     float64
# 좌표정보(Y)     float64
# 영업장주변구분명     object
# dtype: object

# %%
del df['소재지면적']
del df['인허가일자']
del df['인허가취소일자']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소재지면적'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.head()
# Out:
#    개방자치단체코드                    관리번호  영업상태코드  영업상태명  상세영업상태코드 상세영업상태명  폐업일자  \
# 0   3000000  3000000-101-1995-05829       1  영업/정상         1      영업   NaN
# 1   3000000  3000000-101-2002-11872       1  영업/정상         1      영업   NaN
# 2   3000000  3000000-101-1990-03102       1  영업/정상         1      영업   NaN
# 3   3000000  3000000-101-1990-01952       1  영업/정상         1      영업   NaN
# 4   3000000  3000000-101-1991-06486       1  영업/정상         1      영업   NaN
#
#    휴업시작일자  휴업종료일자  재개업일자  ...                         도로명주소  도로명우편번호  \
# 0     NaN     NaN    NaN  ...       서울특별시 종로구 평창길 352 (평창동)   3004.0
# 1     NaN     NaN    NaN  ...  서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0
# 2     NaN     NaN    NaN  ...     서울특별시 종로구 종로41길 10 (종로6가)   3124.0
# 3     NaN     NaN    NaN  ...   서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0
# 4     NaN     NaN    NaN  ...        서울특별시 종로구 종로 289 (창신동)   3101.0
#
#         사업장명        최종수정일자  데이터갱신구분          데이터갱신일자  업태구분명      좌표정보(X)  \
# ...

# %%
del df['최종수정일자']

# %%
df.dtypes
# Out:
# 개방자치단체코드      int64
# 관리번호         object
# 영업상태코드        int64
# 영업상태명        object
# 상세영업상태코드      int64
# 상세영업상태명      object
# 폐업일자        float64
# 휴업시작일자      float64
# 휴업종료일자      float64
# 재개업일자       float64
# 전화번호         object
# 소재지우편번호     float64
# 지번주소         object
# 도로명주소        object
# 도로명우편번호     float64
# 사업장명         object
# 데이터갱신구분      object
# 데이터갱신일자      object
# 업태구분명        object
# 좌표정보(X)     float64
# 좌표정보(Y)     float64
# 영업장주변구분명     object
# dtype: object

# %%
del df['소재지우편번호']
del df['관리번호']
del df['개방자치단체코드']
del df['휴업시작일자']
del df['휴업종료일자']

# %%
df.head()
# Out:
#    영업상태코드  영업상태명  상세영업상태코드 상세영업상태명  폐업일자  재개업일자        전화번호  \
# 0       1  영업/정상         1      영업   NaN    NaN  02 3960044
# 1       1  영업/정상         1      영업   NaN    NaN         NaN
# 2       1  영업/정상         1      영업   NaN    NaN  02 7653726
# 3       1  영업/정상         1      영업   NaN    NaN  02 7372214
# 4       1  영업/정상         1      영업   NaN    NaN         NaN
#
#                       지번주소                         도로명주소  도로명우편번호       사업장명  \
# 0   서울특별시 종로구 평창동 110-1번지        서울특별시 종로구 평창길 352 (평창동)   3004.0     북악파크부페
# 1      서울특별시 종로구 인사동 98번지   서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0   시민식당 2호점
# 2  서울특별시 종로구 종로6가 129-1번지      서울특별시 종로구 종로41길 10 (종로6가)   3124.0       일번우동
# 3      서울특별시 종로구 통인동 27-2    서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0      서촌소국밥
# 4     서울특별시 종로구 창신동 696-1         서울특별시 종로구 종로 289 (창신동)   3101.0  빽다방 동대문역점
#
#   데이터갱신구분          데이터갱신일자 업태구분명      좌표정보(X)      좌표정보(Y) 영업장주변구분명
# 0       I  2018.8.31 23:59   뷔페식  197993.2057  456584.6271       기타
# ...

# %%
del df['전화번호']

# %%
del df['영업장주변구분명']

# %%
df.head()
# Out:
#    영업상태코드  영업상태명  상세영업상태코드 상세영업상태명  폐업일자  재개업일자                     지번주소  \
# 0       1  영업/정상         1      영업   NaN    NaN   서울특별시 종로구 평창동 110-1번지
# 1       1  영업/정상         1      영업   NaN    NaN      서울특별시 종로구 인사동 98번지
# 2       1  영업/정상         1      영업   NaN    NaN  서울특별시 종로구 종로6가 129-1번지
# 3       1  영업/정상         1      영업   NaN    NaN      서울특별시 종로구 통인동 27-2
# 4       1  영업/정상         1      영업   NaN    NaN     서울특별시 종로구 창신동 696-1
#
#                           도로명주소  도로명우편번호       사업장명 데이터갱신구분          데이터갱신일자  \
# 0       서울특별시 종로구 평창길 352 (평창동)   3004.0     북악파크부페       I  2018.8.31 23:59
# 1  서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0   시민식당 2호점       I  2018.8.31 23:59
# 2     서울특별시 종로구 종로41길 10 (종로6가)   3124.0       일번우동       I  2018.8.31 23:59
# 3   서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0      서촌소국밥       U  2021.12.31 2:40
# 4        서울특별시 종로구 종로 289 (창신동)   3101.0  빽다방 동대문역점       U    2020.8.2 2:40
#
#   업태구분명      좌표정보(X)      좌표정보(Y)
# ...

# %%
del df['재개업일자']
del df['폐업일자']

# %%
df.head()
# Out:
#    영업상태코드  영업상태명  상세영업상태코드 상세영업상태명                     지번주소  \
# 0       1  영업/정상         1      영업   서울특별시 종로구 평창동 110-1번지
# 1       1  영업/정상         1      영업      서울특별시 종로구 인사동 98번지
# 2       1  영업/정상         1      영업  서울특별시 종로구 종로6가 129-1번지
# 3       1  영업/정상         1      영업      서울특별시 종로구 통인동 27-2
# 4       1  영업/정상         1      영업     서울특별시 종로구 창신동 696-1
#
#                           도로명주소  도로명우편번호       사업장명 데이터갱신구분          데이터갱신일자  \
# 0       서울특별시 종로구 평창길 352 (평창동)   3004.0     북악파크부페       I  2018.8.31 23:59
# 1  서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0   시민식당 2호점       I  2018.8.31 23:59
# 2     서울특별시 종로구 종로41길 10 (종로6가)   3124.0       일번우동       I  2018.8.31 23:59
# 3   서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0      서촌소국밥       U  2021.12.31 2:40
# 4        서울특별시 종로구 종로 289 (창신동)   3101.0  빽다방 동대문역점       U    2020.8.2 2:40
#
#   업태구분명      좌표정보(X)      좌표정보(Y)
# 0   뷔페식  197993.2057  456584.6271
# 1    한식  198681.5719  452050.2743
# 2    분식  200533.4536  452156.9003
# ...

# %%
new_df = df[df['상세영업상태명']=='영업']

# %%
new_df.head()
# Out:
#    영업상태코드  영업상태명  상세영업상태코드 상세영업상태명                     지번주소  \
# 0       1  영업/정상         1      영업   서울특별시 종로구 평창동 110-1번지
# 1       1  영업/정상         1      영업      서울특별시 종로구 인사동 98번지
# 2       1  영업/정상         1      영업  서울특별시 종로구 종로6가 129-1번지
# 3       1  영업/정상         1      영업      서울특별시 종로구 통인동 27-2
# 4       1  영업/정상         1      영업     서울특별시 종로구 창신동 696-1
#
#                           도로명주소  도로명우편번호       사업장명 데이터갱신구분          데이터갱신일자  \
# 0       서울특별시 종로구 평창길 352 (평창동)   3004.0     북악파크부페       I  2018.8.31 23:59
# 1  서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0   시민식당 2호점       I  2018.8.31 23:59
# 2     서울특별시 종로구 종로41길 10 (종로6가)   3124.0       일번우동       I  2018.8.31 23:59
# 3   서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0      서촌소국밥       U  2021.12.31 2:40
# 4        서울특별시 종로구 종로 289 (창신동)   3101.0  빽다방 동대문역점       U    2020.8.2 2:40
#
#   업태구분명      좌표정보(X)      좌표정보(Y)
# 0   뷔페식  197993.2057  456584.6271
# 1    한식  198681.5719  452050.2743
# 2    분식  200533.4536  452156.9003
# ...

# %%
print(new_df)
# Out:
#         영업상태코드  영업상태명  상세영업상태코드 상세영업상태명                           지번주소  \
# 0            1  영업/정상         1      영업         서울특별시 종로구 평창동 110-1번지
# 1            1  영업/정상         1      영업            서울특별시 종로구 인사동 98번지
# 2            1  영업/정상         1      영업        서울특별시 종로구 종로6가 129-1번지
# 3            1  영업/정상         1      영업            서울특별시 종로구 통인동 27-2
# 4            1  영업/정상         1      영업           서울특별시 종로구 창신동 696-1
# ...        ...    ...       ...     ...                            ...
# 480799       1  영업/정상         1      영업      서울특별시 동대문구 이문동 316-2 지하1층
# 480804       1  영업/정상         1      영업  서울특별시 노원구 하계동 256-11 보스턴 산부인과
# 480806       1  영업/정상         1      영업       서울특별시 강남구 신사동 609-1 지하1층
# 480807       1  영업/정상         1      영업       서울특별시 용산구 한강로2가 116-1 1층
# 480809       1  영업/정상         1      영업            서울특별시 종로구 명륜3가 1-14
#
#                                       도로명주소  도로명우편번호           사업장명 데이터갱신구분  \
# ...

# %%
df = new_df

# %%
new_df = df[df['도로명주소'].str.contains('강남구')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 new_df = df[df['도로명주소'].str.contains('강남구')]
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:144, in is_bool_indexer(key)
#     140     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     141     if lib.infer_dtype(key) == "boolean" and isna(key).any():
# ...

# %%
df['도로명주소'] = df['도로명주소'].fillna('0')
# Out:
# /var/folders/d2/20dks6yj46b_077x0h5fmr740000gn/T/ipykernel_4411/3872512382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['도로명주소'] = df['도로명주소'].fillna('0')

# %%
df_check = df[df['도로명주소'] == '0']

# %%
print(df_check)
# Out:
#         영업상태코드  영업상태명  상세영업상태코드 상세영업상태명                         지번주소 도로명주소  \
# 39           1  영업/정상         1      영업        서울특별시 종로구 내수동 61-1번지      0
# 44           1  영업/정상         1      영업      서울특별시 종로구 신문로2가 19-0번지      0
# 46           1  영업/정상         1      영업       서울특별시 종로구 명륜3가 53-0번지      0
# 48           1  영업/정상         1      영업       서울특별시 종로구 명륜3가 53-0번지      0
# 58           1  영업/정상         1      영업         서울특별시 종로구 내수동 153번지      0
# ...        ...    ...       ...     ...                          ...   ...
# 478712       1  영업/정상         1      영업         서울특별시 종로구 명륜2가 142-4     0
# 479072       1  영업/정상         1      영업    서울특별시 종로구 명륜2가 114-2 지상1층     0
# 479974       1  영업/정상         1      영업     서울특별시 영등포구 대림동 1032-0 19     0
# 480357       1  영업/정상         1      영업  서울특별시 성동구 홍익동 122-10 (지상1층)     0
# 480664       1  영업/정상         1      영업     서울특별시 광진구 자양동 115-9 (A동)     0
#
# ...

# %%
df = df[df['도로명주소'].str.contains('강남구')]

# %%
print(df)
# Out:
#         영업상태코드  영업상태명  상세영업상태코드 상세영업상태명                               지번주소  \
# 219          1  영업/정상         1      영업             서울특별시 강남구 도곡동 411 빌딩 숨
# 381          1  영업/정상         1      영업  서울특별시 강남구 논현동 160-11 louis(루이스빌딩)
# 2072         1  영업/정상         1      영업    서울특별시 강남구 역삼동 707-34 한신인터밸리24빌딩
# 2263         1  영업/정상         1      영업         서울특별시 강남구 논현동 230-2 뜨레빌 빌라
# 2388         1  영업/정상         1      영업           서울특별시 강남구 논현동 261 현대인텔렉스
# ...        ...    ...       ...     ...                                ...
# 480687       1  영업/정상         1      영업                서울특별시 강남구 신사동 526-3
# 480708       1  영업/정상         1      영업                서울특별시 강남구 개포동 165-5
# 480733       1  영업/정상         1      영업               서울특별시 강남구 역삼동 735-36
# 480759       1  영업/정상         1      영업            서울특별시 강남구 개포동 1257 까사밀라
# 480806       1  영업/정상         1      영업           서울특별시 강남구 신사동 609-1 지하1층
#
#                                                    도로명주소  도로명우편번호  \
# ...

# %%
df.to_csv("강남구 일반 음식점.csv",mode = 'w',encoding='CP949')
