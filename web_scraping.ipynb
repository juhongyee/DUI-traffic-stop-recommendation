# %%
from webdriver_manager.chrome import ChromeDriverManager # 자동으로 크롬드라이버(가상브라우저) 파일을 다운로드해주는 라이브러리
from selenium.webdriver.chrome.service import Service # 다운로드된 크롬드라이버 파일을 연결하기 위해 활용

from selenium import webdriver
from bs4 import BeautifulSoup

from selenium.webdriver.common.keys import Keys

import pandas as pd
import time
import datetime 
from dateutil import rrule

import warnings
warnings.filterwarnings("ignore") # 불필요한 Warning 메시지를 꺼줍니다.

# %%
place = '강남'
keyword = '이자카야'
url = "https://pcmap.place.naver.com/restaurant/list?query="+place+"%20"+keyword

# %%
service = Service(executable_path=ChromeDriverManager().install()) 
driver = webdriver.Chrome(service=service)

driver.get(url)
time.sleep(3)
name = []
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache

# %%
#driver.switch_to.frame("searchIframe")

# %%
# # driver.execute_script("return window.pageYOffset")
# # driver.execute_script("window.scrollTo(500,500)")
# lastHeight = driver.execute_script("return document.body.scrollHeight")
# print(lastHeight)
# driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)
# #driver.execute_script("window.scrollTo(300, document.body.scrollHeight);")
# newHeight = driver.execute_script("return document.body.scrollHeight")
# print(newHeight)

# %%
itemlist = driver.find_element_by_id('_pcmap_list_scroll_container')

while(True):
    sec = 20
    i = 0
    while True:
        #스크롤이 같은 길이처럼 보여도 data양이 많으면 더 길이가 긴 것
        #lastHeight = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("arguments[0].scrollBy(0,document.body.scrollHeight)",itemlist)
        driver.implicitly_wait(3)
        i +=1
        #newHeight = driver.execute_script("return document.body.scrollHeight")
        if sec == i:
             break
                
    web = driver.page_source
    source = BeautifulSoup(web, 'html.parser')
    name.append(source.find_all('span',{'class' : 'place_bluelink TYaxT'}))
    origin_path = '/html/body/div[3]/div/div[2]/div[2]/a[7]'
    driver.find_element_by_xpath(origin_path).click()
    #페이지번호가 같으면 종료
    if(source.find('a',{'class' : 'mBN2s qxokY'})==BeautifulSoup(driver.page_source, 'html.parser').find('a',{'class' : 'mBN2s qxokY'})):
        print(source.find('a',{'class' : 'mBN2s qxokY'}))
        print(BeautifulSoup(driver.page_source, 'html.parser').find('a',{'class' : 'mBN2s qxokY'}))
        break    
# print("scroll fin.")
print("됐다")
# Out:
# <a class="mBN2s qxokY" href="#" role="button" target="_self">6</a>
# <a class="mBN2s qxokY" href="#" role="button" target="_self">6</a>
# 됐다

# %%
for N in name:
    for M in N:
        print(M.get_text())
# Out:
# 수다 삼성1호점
# 수다 청담점
# 시라카와 텐푸라
# 야키토리 요이사
# 갓포 히미츠 X 뱅가드 하이파이 뮤직 라운지
# 코다차야 강남점
# 수다 대치점
# 와라야키 쿠이신보
# 이자카야나무 강남역2호점
# 켄홈1991
# 이자카야 신조
# 쿠시일오이
# 야키토리 토리키치 압구정로데오점
# 토가라시
# 사이
# 마코토 청담점
# 진도켄 이자카야
# 수다 삼성2호점
# 지칸
# 센야 본점
# 마요네즈 신논현점
# 이도
# 타츠야
# 마리모 신사동점
# 청담이상 강남역점
# 이자카야 나무
# 센도수산
# Lu307 이자카야
# 이자카야나무 대치점
# 호시
# 이자카야나무 논현점
# 우오하나
# 하루
# 고우 청담점
# 모토
# 청담류 2호점 Meat Izakaya
# 모로미쿠시 역삼초교점
# 츄라우미 역삼본점
# 로바타 라이브라 카운터
# 갓포 모로미 도산공원점
# 아카라
# 청담류 The First Izakaya
# 로바다야끼 최군
# 신사연어
# 타이쇼
# 도산사카바 카와세미
# 센민이자카야
# 달아
# 쇼쿠도카이
# 논현194
# 수다 삼성1호점
# 수다 청담점
# 시라카와 텐푸라
# 야키토리 요이사
# 갓포 히미츠 X 뱅가드 하이파이 뮤직 라운지
# 코다차야 강남점
# 수다 대치점
# 와라야키 쿠이신보
# 이자카야나무 강남역2호점
# 켄홈1991
# 이자카야 신조
# 쿠시일오이
# 야키토리 토리키치 압구정로데오점
# 토가라시
# 사이
# 마코토 청담점
# 진도켄 이자카야
# 수다 삼성2호점
# 지칸
# 센야 본점
# 마요네즈 신논현점
# 이도
# 타츠야
# 마리모 신사동점
# 청담이상 강남역점
# 이자카야 나무
# 센도수산
# Lu307 이자카야
# 이자카야나무 대치점
# 호시
# 이자카야나무 논현점
# 우오하나
# 하루
# 고우 청담점
# 모토
# 청담류 2호점 Meat Izakaya
# 모로미쿠시 역삼초교점
# 츄라우미 역삼본점
# 로바타 라이브라 카운터
# 갓포 모로미 도산공원점
# 아카라
# 청담류 The First Izakaya
# 로바다야끼 최군
# 신사연어
# 타이쇼
# 도산사카바 카와세미
# 센민이자카야
# 달아
# 쇼쿠도카이
# 논현194
# 이자카야소영 논현점
# 더 간사이
# 경성야시장
# 남오토코 역삼점
# 동경야시장 강남점
# 오다
# 미미스시인생술집
# 오레노유메 선릉본점
# 와후진1호점
# 사이야 강남일원동점
# 갓포슌
# 키노에다
# 기세끼 선릉점
# 청담이상 가로수길점
# 야다이
# 705사케집 선릉점
# 타다이마
# 완소
# 토리니쿠
# 아리
# 리키도잔
# 이자카야겸 2호점
# 료하나
# 피에스타
# 청담이상 차병원점
# 이자카야 겸
# 풍
# 남오토코 대치점
# 야신
# 이끼 이자카야 본점
# 테바사키반초 대치점
# 오조이자카야
# 토노야
# 반스키친
# 도리마틴
# 이자카야 운좋은 횟집
# 라빈이자카야
# 명오뎅빠이자까야
# Kanzi Dinning
# 홍로
# 하코네
# 탄 역삼점
# 송
# 와사
# 우미호타루
# 백천
# 야간비행
# 곤파치야이자카야
# 노보루
# 이자카야 담
# 이자카야소영 논현점
# 더 간사이
# 경성야시장
# 남오토코 역삼점
# 동경야시장 강남점
# 오다
# 미미스시인생술집
# 오레노유메 선릉본점
# 와후진1호점
# 사이야 강남일원동점
# 갓포슌
# 키노에다
# 기세끼 선릉점
# 청담이상 가로수길점
# 야다이
# 705사케집 선릉점
# 타다이마
# 완소
# 토리니쿠
# 아리
# 리키도잔
# 이자카야겸 2호점
# 료하나
# 피에스타
# 청담이상 차병원점
# 이자카야 겸
# 풍
# 남오토코 대치점
# 야신
# 이끼 이자카야 본점
# 테바사키반초 대치점
# 오조이자카야
# 토노야
# 반스키친
# 도리마틴
# 이자카야 운좋은 횟집
# 라빈이자카야
# 명오뎅빠이자까야
# Kanzi Dinning
# 홍로
# 하코네
# 탄 역삼점
# 송
# 와사
# 우미호타루
# 백천
# 야간비행
# 곤파치야이자카야
# 노보루
# 이자카야 담
# 이자카야소영 논현점
# 더 간사이
# 경성야시장
# 남오토코 역삼점
# 동경야시장 강남점
# 오다
# 미미스시인생술집
# 오레노유메 선릉본점
# 와후진1호점
# 사이야 강남일원동점
# 갓포슌
# 키노에다
# 기세끼 선릉점
# 청담이상 가로수길점
# 야다이
# 705사케집 선릉점
# 타다이마
# 완소
# 토리니쿠
# 아리
# 리키도잔
# 이자카야겸 2호점
# 료하나
# 피에스타
# 청담이상 차병원점
# 이자카야 겸
# 풍
# 남오토코 대치점
# 야신
# 이끼 이자카야 본점
# 테바사키반초 대치점
# 오조이자카야
# 토노야
# 반스키친
# 도리마틴
# 이자카야 운좋은 횟집
# 라빈이자카야
# 명오뎅빠이자까야
# Kanzi Dinning
# 홍로
# 하코네
# 탄 역삼점
# 송
# 와사
# 우미호타루
# 백천
# 야간비행
# 곤파치야이자카야
# 노보루
# 이자카야 담
# 호시아이
# 이자카야 찌유
# 한토리
# 코이
# 지금이밤
# 월당
# 한남타츠 대사관로점
# 타비
# 심야식당 하리
# 신월
# 아쿠슈
# 청담이상 교대점
# 오레노 유메
# 아리노마마
# 그늘
# 아도겐
# 도키도키키친
# 토리광
# 도톤보리교대점
# 조우
# 이자카야 공감 강남역점
# 요비
# 유다 잠실새내점
# 백야
# 미타우동
# 천호구르메 별관
# 키엔오
# 나린아토 이자카야
# 갓포더인
# 도톤보리
# 쿠시범
# 코후쿠
# 사쿠라테이엔 문정점
# 완도1957
# 다목당
# 작야
# 하리네즈미
# 수작 선릉
# 10Q
# 하츠코이 오카
# 골목길그집
# 쇼유식당 역삼본점
# 사케리아 잇콘
# 미카식당
# 코코로
# 카마도
# 705 사케집 교대점
# 이자카야 코노미
# 토리아에즈 가락점
# 모쿠

# %%
temp = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[1]/ul/li[1]/div[1]/a/div/div/span[1]')

# %%
driver.implicitly_wait(10)

# %%
driver.close()
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 driver.close()
#       2 driver.quit()
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:937, in WebDriver.close(self)
#     928 def close(self) -> None:
#     929     """
#     930     Closes the current window.
#     931
#    (...)
#     935             driver.close()
#     936     """
# --> 937     self.execute(Command.CLOSE)
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
# --> 424     self.error_handler.check_response(response)
#     425     response['value'] = self._unwrap_value(
#     426         response.get('value', None))
#     427     return response
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=106.0.5249.119)
# Stacktrace:
# 0   chromedriver                        0x0000000105052598 chromedriver + 4404632
# 1   chromedriver                        0x0000000104fd9fa3 chromedriver + 3911587
# 2   chromedriver                        0x0000000104c86e6a chromedriver + 425578
# 3   chromedriver                        0x0000000104c667b3 chromedriver + 292787
# 4   chromedriver                        0x0000000104ce0b8d chromedriver + 793485
# 5   chromedriver                        0x0000000104ce72db chromedriver + 819931
# 6   chromedriver                        0x0000000104cdcd68 chromedriver + 777576
# 7   chromedriver                        0x0000000104cb1ced chromedriver + 601325
# 8   chromedriver                        0x0000000104cb2e51 chromedriver + 605777
# 9   chromedriver                        0x00000001050220ce chromedriver + 4206798
# 10  chromedriver                        0x0000000105026797 chromedriver + 4224919
# 11  chromedriver                        0x000000010502da4f chromedriver + 4254287
# 12  chromedriver                        0x00000001050274da chromedriver + 4228314
# 13  chromedriver                        0x000000010500023f chromedriver + 4067903
# 14  chromedriver                        0x00000001050446a8 chromedriver + 4347560
# 15  chromedriver                        0x0000000105044816 chromedriver + 4347926
# 16  chromedriver                        0x00000001050598fe chromedriver + 4434174
# 17  libsystem_pthread.dylib             0x00007ff80319f259 _pthread_start + 125
# 18  libsystem_pthread.dylib             0x00007ff80319ac7b thread_start + 15

# %%
#한 번에 끝내는 code
from webdriver_manager.chrome import ChromeDriverManager # 자동으로 크롬드라이버(가상브라우저) 파일을 다운로드해주는 라이브러리
from selenium.webdriver.chrome.service import Service # 다운로드된 크롬드라이버 파일을 연결하기 위해 활용

from selenium import webdriver
from bs4 import BeautifulSoup

from selenium.webdriver.common.keys import Keys

import pandas as pd
import time
import datetime
import csv
from dateutil import rrule

import warnings
warnings.filterwarnings("ignore") # 불필요한 Warning 메시지를 꺼줍니다.

place = '강남'
keyword = ['주점','이자카야','술집','바(bar)','유흥주점','포장마차','감성주점','요리주점','맥주']
name = []

for i in range(len(keyword)):
    url = "https://pcmap.place.naver.com/restaurant/list?query="+place+"%20"+keyword[i]
    
    service = Service(executable_path=ChromeDriverManager().install()) 
    driver = webdriver.Chrome(service=service)

    driver.get(url)
    time.sleep(3)
    
    itemlist = driver.find_element_by_id('_pcmap_list_scroll_container')
    #len_item = driver.find_all()
    while(True):
        sec = 20
        i = 0
        while True:
            #스크롤이 같은 길이처럼 보여도 data양이 많으면 더 길이가 긴 것
            #lastHeight = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script("arguments[0].scrollBy(0,document.body.scrollHeight)",itemlist)
            time.sleep(3)
            i +=1
            #newHeight = driver.execute_script("return document.body.scrollHeight")
            if sec == i:
                 break

        web = driver.page_source
        source = BeautifulSoup(web, 'html.parser')
        name.append(source.find_all('span',{'class' : 'place_bluelink TYaxT'}))
        driver.find_elements_by_class_name('eUTV2')[1].click()
        #페이지번호가 같으면 종료
        if(source.find('a',{'class' : 'mBN2s qxokY'})==BeautifulSoup(driver.page_source, 'html.parser').find('a',{'class' : 'mBN2s qxokY'})):
            break
            
with open("술집_scraping.csv",'a',newline='',encoding='cp949') as f:
    wr = csv.writer(f)
    for N in name:
        for M in N:
            wr.writerow(M)
f.close()
driver.close()
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# Driver [/Users/juhong/.wdm/drivers/chromedriver/mac64/106.0.5249.61/chromedriver] found in cache
